# %%
import os
import pandas as pd
import numpy as np
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-9aa587b7-70ff-417e-b2d6-a8eaeff53880" name="files[]" multiple disabled />
#      <output id="result-9aa587b7-70ff-417e-b2d6-a8eaeff53880">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test_2.csv to test_2.csv
# ...

# %%
#os.unlink('test_2.csv')
# !ls
# Out:
# sample_data  test_2.csv

# %%
data_1= pd.read_csv('test_2.csv')

# %%
data_1
# Out:
#     month_number  Year month  Number of request
# 0              9  2012   Sep                2.0
# 1             12  2012   Dec                1.0
# 2              8  2013   Aug               20.0
# 3              9  2013   Sep               30.0
# 4             10  2013   Oct               38.0
# 5             11  2013   Nov               28.0
# 6             12  2013   Dec               13.0
# 7              1  2014   Jan               51.0
# 8              2  2014   Feb               43.0
# 9              3  2014   Mar               50.0
# 10             4  2014   Apr               38.0
# 11             5  2014   May               33.0
# 12             6  2014   Jun               35.0
# 13             7  2014   Jul               35.0
# 14             8  2014   Aug               24.0
# 15             9  2014   Sep               40.0
# 16            10  2014   Oct               47.0
# 17            11  2014   Nov               46.0
# 18            12  2014   Dec               23.0
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.neighbors import  KNeighborsRegressor

# %%
x=data_1.iloc[0:72,:2]
y=data_1.iloc[0:72,3:]
x_pred=data_1.iloc[72:,:2]
mon=data_1.iloc[72:,2:3]

# %%
lin= LinearRegression()
lin.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
 mon['NOR']= [i[0] for i in lin.predict(x_pred)]

# %%
mon
# Out:
#    month        NOR
# 72   Jun  44.180627
# 73   Jul  43.292584
# 74   Aug  42.404540
# 75   Sep  41.516497
# 76   Oct  40.628453
# 77   Nov  39.740409
# 78   Dec  38.852366
# 79   Jan  51.008932
# 80   Feb  50.120888
# 81   Mar  49.232844
# 82   Apr  48.344801
# 83   May  47.456757
# 84   Jun  46.568713
# 85   Jul  45.680670
# 86   Aug  44.792626
# 87   Sep  43.904583
# 88   Oct  43.016539
# 89   Nov  42.128495

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='month', y='NOR', data=mon)
plt.show()
